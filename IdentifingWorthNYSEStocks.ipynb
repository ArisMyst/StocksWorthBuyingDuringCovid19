# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
from googlefinance import getQuotes
# %matplotlib inline

# %%
df = pd.read_csv("companylist2.csv")
df
# Out:
#      Symbol
# 0       EAE
# 1       EAI
# 2       ETR
# 3       ELC
# 4       ELJ
# ...     ...
# 1674    ZBH
# 1675    ZTS
# 1676    ZTO
# 1677    ZUO
# 1678   ZYME
#
# [1679 rows x 1 columns]

# %%
tickers = df['Symbol']

# %%
#for ticker in tickers:
#    try:
#        start_date = '2019-10-01'
#        end_date = '2019-12-31'
#        panel_data = data.DataReader(ticker, 'yahoo', start_date, end_date)
#        close = panel_data['Close']
#    except KeyError:
#        continue

# %%
# Define the instruments to download. We would like to see Apple, Microsoft and the S&P500 index.
StocksToBuy = []

for ticker in tickers:
    print(ticker)
    start_date = '2019-10-01'
    end_date = '2019-12-31'
    try:
        panel_data = data.DataReader(ticker, 'yahoo', start_date, end_date)
    except:
        continue
    close = panel_data['Close']
    if (close.mean()*0.2)>(close.mean()-close.min()) and (close.mean()*0.2)>(close.max()-close.mean()):
        start_date2 = '2020-03-18'
        end_date2 = '2020-05-01'
        panel_data2 = data.DataReader(ticker, 'yahoo', start_date2, end_date2)
        close2 = panel_data2['Close']       
        if (close.mean()*0.5)>(close2.mean()):  
            start_date3 = '2020-05-01'
            end_date3 = '2020-05-01'
            panel_data3 = data.DataReader(ticker, 'yahoo', start_date3, end_date3)
            close3 = panel_data3['Close']
            if (close2.mean())>(close3.mean()):  
                StocksToBuy.append(ticker)
    
    
# We would like all available data from 01/01/2000 until 12/31/2016.
#start_date = '2019-10-01'
#end_date = '2020-05-01'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
#panel_data = data.DataReader(tickers, 'yahoo', start_date, end_date)
# Out:
# EAE
# EAI
# ETR
# ELC
# ELJ
# ELU
# EMP
# ENJ
# ENO
# EZT
# EPD
# EVC
# ENV
# NVST
# EVA
# ENZ
# EOG
# EPAM
# EPR
# EQM
# EQT
# EFX
# EQNR
# EQH
# ETRN
# EQC
# ELS
# EQR
# EQS
# ERA
# EROS
# ESE
# ESNT
# EPRT
# WTRG
# WTRU
# ESS
# EL
# ETH
# EURN
# EEA
# EB
# EVR
# RE
# EVRG
# EVRI
# ES
# EVTC
# EVH
# AQUA
# XAN
# EXPR
# EXTN
# EXR
# XOM
# FNB
# FN
# FDS
# FICO
# SFUN
# FPAC
# FTCH
# FPI
# FSLY
# FBK
# FFG
# AGM
# FRT
# FSS
# FHI
# FMN
# FDX
# RACE
# FOE
# FG
# FCAU
# FNF
# FIS
# FMO
# FINV
# FAF
# FBP
# FCF
# FHN
# FR
# AG
# FRC
# FFA
# FMY
# FDEU
# FIF
# FSD
# FPF
# FEI
# FPL
# FIV
# FCT
# FGB
# FEO
# FAM
# FE
# FIT
# FPH
# FVRR
# FBC
# DFP
# PFD
# PFO
# FFC
# FLC
# FLT
# FLNG
# FND
# FTK
# FLO
# FLS
# FLR
# FLY
# FEAC
# FMC
# FMX
# FL
# F
# FOR
# FTS
# FTV
# FTAI
# FSM
# FBHS
# FET
# FBM
# FCPT
# FEDU
# FNV
# FC
# FSB
# BEN
# FT
# FI
# FCX
# FMS
# FDP
# RESI
# FRO
# FSK
# FCN
# FTSI
# FF
# GCV
# GAB
# GGZ
# GGT
# GUT
# GCAP
# GLEO
# GBL
# GNT
# GME
# GCI
# GPS
# GTX
# IT
# GLOG
# ...

# %%
StocksToBuy
# Out:
# ['FTK',
#  'FLY',
#  'FI',
#  'TV',
#  'HP',
#  'HTZ',
#  'HXL',
#  'ING',
#  'IVR',
#  'JCP',
#  'KTP',
#  'LINX',
#  'MAC',
#  'M',
#  'MDLY',
#  'MDP',
#  'MFA',
#  'HJV',
#  'JWN',
#  'NOA',
#  'RWT',
#  'RYB',
#  'SMHI',
#  'JBN',
#  'JBR',
#  'SPR',
#  'SPLP',
#  'SPN',
#  'TISI',
#  'TSE',
#  'VHI',
#  'VJET',
#  'WPG']

# %%
close3.describe()
# Out:
# count    2.000000
# mean     0.889150
# std      0.001202
# min      0.888300
# 25%      0.888725
# 50%      0.889150
# 75%      0.889575
# max      0.890000
# Name: Close, dtype: float64

# %%
close2.describe()
# Out:
# count    34.000000
# mean      0.690588
# std       0.155133
# min       0.430000
# 25%       0.555000
# 50%       0.700000
# 75%       0.777500
# max       0.960000
# Name: Close, dtype: float64

# %%
close.describe()
# Out:
# count    64.000000
# mean      2.531250
# std       0.147911
# min       2.270000
# 25%       2.425000
# 50%       2.520000
# 75%       2.600000
# max       2.880000
# Name: Close, dtype: float64

# %%
close.mean()*0.2
# Out:
# 0.5062499977648258

# %%
close.max()
# Out:
# 2.880000114440918

# %%
close.min()
# Out:
# 2.2699999809265137

# %%
StocksToBuy
# Out:
# ['CCO']

# %%
panel_data.head()
# Out:
#             High   Low  Open  Close   Volume  Adj Close
# Date
# 2019-10-01  9.38  8.99  8.99   9.32  1445800       9.32
# 2019-10-02  9.35  8.96  9.20   9.24  1316700       9.24
# 2019-10-03  9.27  8.80  9.18   9.19  1003600       9.19
# 2019-10-04  9.32  9.07  9.23   9.27   733700       9.27
# 2019-10-07  9.56  9.09  9.17   9.49  1175100       9.49

# %%
plt.plot(panel_data)
# Out:
# ...
#  ...]

# %%
panel_data.to_csv('all_data.csv')

# %%
# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

# Reindexing will insert missing values (NaN) for the dates that were not present
# in the original set. To cope with this, we can fill the missing by replacing them
# with the latest available price for each instrument.
close = close.fillna(method='ffill')

# %%
print(all_weekdays)

# DatetimeIndex(['2010-01-01', '2010-01-04', '2010-01-05', '2010-01-06',
#               '2010-01-07', '2010-01-08', '2010-01-11', '2010-01-12',
#               '2010-01-13', '2010-01-14',
#               ...
#               '2016-12-19', '2016-12-20', '2016-12-21', '2016-12-22',
#               '2016-12-23', '2016-12-26', '2016-12-27', '2016-12-28',
#               '2016-12-29', '2016-12-30'],
#              dtype='datetime64[ns]', length=1826, freq='B')
# Out:
# DatetimeIndex(['2019-10-01', '2019-10-02', '2019-10-03', '2019-10-04',
#                '2019-10-07', '2019-10-08', '2019-10-09', '2019-10-10',
#                '2019-10-11', '2019-10-14',
#                ...
#                '2020-04-20', '2020-04-21', '2020-04-22', '2020-04-23',
#                '2020-04-24', '2020-04-27', '2020-04-28', '2020-04-29',
#                '2020-04-30', '2020-05-01'],
#               dtype='datetime64[ns]', length=154, freq='B')

# %%
close.head(10)
# Out:
# Symbols      CARS   CCO    MRO
# 2019-10-01   9.32  2.48  11.79
# 2019-10-02   9.24  2.40  11.30
# 2019-10-03   9.19  2.44  11.66
# 2019-10-04   9.27  2.50  11.56
# 2019-10-07   9.49  2.48  11.41
# 2019-10-08   9.32  2.41  11.09
# 2019-10-09   9.41  2.41  11.19
# 2019-10-10   9.74  2.45  11.40
# 2019-10-11  10.11  2.46  11.74
# 2019-10-14  10.32  2.40  11.78

# %%
close.describe()
# Out:
# Symbols        CARS         CCO         MRO
# count    154.000000  154.000000  154.000000
# mean       9.773766    2.111234    9.839416
# std        3.304971    0.844897    3.633789
# min        3.610000    0.430000    3.120000
# 25%        6.927500    1.410000    5.917500
# 50%       11.380000    2.500000   11.670000
# 75%       12.385000    2.695000   12.215000
# max       13.460000    3.050000   13.960000

# %%
# Get the MSFT timeseries. This now returns a Pandas Series object indexed by date.
msft = close.loc[:, 'CARS']

# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling_msft = msft.rolling(window=20).mean()
long_rolling_msft = msft.rolling(window=100).mean()

# Plot everything by leveraging the very powerful matplotlib package
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(msft.index, msft, label='CARS')
ax.plot(short_rolling_msft.index, short_rolling_msft, label='20 days rolling')
ax.plot(long_rolling_msft.index, long_rolling_msft, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Adjusted closing price ($)')
ax.legend()
